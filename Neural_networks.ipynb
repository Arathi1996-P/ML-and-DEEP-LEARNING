# %% [markdown]
# <a href="https://colab.research.google.com/github/Arathi1996-P/ML-and-DEEP-LEARNING/blob/main/Neural_networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Dropout
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ce1e2bc3-8334-4acf-bc1b-508e757ab7cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce1e2bc3-8334-4acf-bc1b-508e757ab7cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['housing.csv']))
df
# Out:
#        Unnamed: 0  MedInc  HouseAge  AveRooms  AveBedrms  Population  \
# 0               0  8.3252      41.0  6.984127   1.023810       322.0
# 1               1  8.3014      21.0  6.238137   0.971880      2401.0
# 2               2  7.2574      52.0  8.288136   1.073446       496.0
# 3               3  5.6431      52.0  5.817352   1.073059       558.0
# 4               4  3.8462      52.0  6.281853   1.081081       565.0
# ...           ...     ...       ...       ...        ...         ...
# 20635       20635  1.5603      25.0  5.045455   1.133333       845.0
# 20636       20636  2.5568      18.0  6.114035   1.315789       356.0
# 20637       20637  1.7000      17.0  5.205543   1.120092      1007.0
# 20638       20638  1.8672      18.0  5.329513   1.171920       741.0
# 20639       20639  2.3886      16.0  5.254717   1.162264      1387.0
#
#        AveOccup  Latitude  Longitude  MedHouseVal
# 0      2.555556     37.88    -122.23        4.526
# ...

# %%
x = df.drop('MedHouseVal',axis=1).values
y = df.MedHouseVal

# %%
from sklearn.model_selection import train_test_split
x_train, x_val_and_test, y_train,y_val_and_test = train_test_split(x,y, test_size=0.20)
x_val, x_test, y_val, y_test = train_test_split(x_val_and_test, y_val_and_test, test_size=0.5)

# %%
print(x_train.shape, x_val.shape, x_test.shape, y_train.shape, y_val.shape, y_test.shape)
# Out:
# (16512, 9) (2064, 9) (2064, 9) (16512,) (2064,) (2064,)

# %%
model = Sequential([
    Dense(30, activation='relu', input_shape=(9,)),
    Dropout(0.2),
    Dense(30, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid'),
    Dropout(0.2)
])

# %%
model.compile(optimizer='sgd',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train, y_train,batch_size=32, epochs=100,validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 516/516 [==============================] - 3s 4ms/step - loss: -6.4960 - accuracy: 0.0022 - val_loss: -16.6300 - val_accuracy: 0.0015
# Epoch 2/100
# 516/516 [==============================] - 1s 2ms/step - loss: -6.3390 - accuracy: 0.0024 - val_loss: -16.6300 - val_accuracy: 0.0015
# Epoch 3/100
# 516/516 [==============================] - 1s 2ms/step - loss: -6.5841 - accuracy: 0.0025 - val_loss: -16.6300 - val_accuracy: 0.0015
# Epoch 4/100
# 516/516 [==============================] - 1s 2ms/step - loss: -6.7366 - accuracy: 0.0022 - val_loss: -16.6300 - val_accuracy: 0.0015
# Epoch 5/100
# 516/516 [==============================] - 1s 2ms/step - loss: -6.6745 - accuracy: 0.0024 - val_loss: -16.6300 - val_accuracy: 0.0015
# Epoch 6/100
# 516/516 [==============================] - 1s 2ms/step - loss: -6.4871 - accuracy: 0.0023 - val_loss: -16.6300 - val_accuracy: 0.0015
# Epoch 7/100
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 65/65 [==============================] - 0s 2ms/step - loss: -16.8298 - accuracy: 0.0039
# [-16.829845428466797, 0.0038759689778089523]

# %%
model2 = Sequential([
    Dense(100, activation='relu', input_shape=(9,)),
    Dense(100, activation='relu'),
    Dense(100, activation='relu'),
    Dense(100, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
model2.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
hist=model2.fit(x_train, y_train,batch_size=32, epochs=100,validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 516/516 [==============================] - 2s 4ms/step - loss: -1831199918760839348224.0000 - accuracy: 0.0031 - val_loss: -1869736798559783616512.0000 - val_accuracy: 0.0015
# Epoch 2/100
# 516/516 [==============================] - 1s 2ms/step - loss: -1873158549114166706176.0000 - accuracy: 0.0031 - val_loss: -1912439367276557238272.0000 - val_accuracy: 0.0015
# Epoch 3/100
# 516/516 [==============================] - 1s 2ms/step - loss: -1915779067875229171712.0000 - accuracy: 0.0031 - val_loss: -1955809735375576891392.0000 - val_accuracy: 0.0015
# Epoch 4/100
# 516/516 [==============================] - 1s 2ms/step - loss: -1959204745807172468736.0000 - accuracy: 0.0031 - val_loss: -2000004543681382055936.0000 - val_accuracy: 0.0015
# Epoch 5/100
# 516/516 [==============================] - 1s 3ms/step - loss: -2003348607142193004544.0000 - accuracy: 0.0031 - val_loss: -2044946245837888946176.0000 - val_accuracy: 0.0015
# Epoch 6/100
# ...

# %%
model2.evaluate(x_test, y_test)
# Out:
# 65/65 [==============================] - 0s 2ms/step - loss: -11906752928730845282304.0000 - accuracy: 0.0039
# [-1.1906752928730845e+22, 0.0038759689778089523]

# %%
prediction = model2.predict([x_test])
print(prediction)
# Out:
# 65/65 [==============================] - 0s 7ms/step
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]]

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'])
plt.show()

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()
